# %% [markdown]
# # Gaussian Process

# %% [markdown]
# ## dataset
# 1차원의 input과 1차원의 output을 갖는 sin function random data를 100개 생성한다. (without noise model)

# %%
import numpy as np
from sklearn import datasets
data_x, data_y = datasets.make_regression(n_samples=100, n_features=1, noise=.0)
y_min_max = (np.max( data_y ) - np.min( data_y ))
#data_y = np.sin( data_y / y_min_max * np.pi * 2.0 )
data_y = (np.sin( data_x ) + 0.5).T[0]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

x = np.arange(-3.0, 3.0, 0.1)

fig = plt.figure()
axis = fig.add_subplot(111)
axis.plot( x, np.sin(x) + 0.5 )
axis.scatter(data_x, data_y, c=data_y)
# Out:
# /usr/lib/pymodules/python2.7/matplotlib/collections.py:548: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':

# %% [markdown]
# ## RBF convariance function

# %%
def k(x1, x2, alpha=1.0, ell=1.0):
    d = x1 - x2
    
    return alpha * np.exp( - np.dot(d, d) / ell )

fig = plt.figure()
axis = fig.add_subplot(111)
axis.plot( x, [k(0, v) for v in x] )
axis.plot( x, [k(0, v, ell=5.0) for v in x] )
axis.plot( x, [k(0, v, alpha=3.0) for v in x] )

# %% [markdown]
# ## Gaussian Process without noise

# %%
def mu(covariance, y):
    _y = np.matmul( covariance, y ).T
    _ =  _y / np.sum( covariance, axis=1 )
    return _

def GP(train_x, train_y, test_x):
    K = np.array( [[k(x, y) for y in train_x] for x in train_x] )

    # for test
    K_star_star = np.array( [[k(x, y) for y in test_x] for x in test_x] )
    K_star = np.array( [[k(x, y) for y in test_x] for x in train_x])
    
    t = np.matmul( K_star.T, np.linalg.pinv(K) )
    mu_star = mu(K_star.T, train_y) + np.matmul(t, (train_y - mu(K, train_y)) )
    sigma_star = K_star_star - np.matmul( t, K_star )
    
    return mu_star, sigma_star

# %%
train_x, train_y = data_x[:2], data_y[:2]
prediction = GP(train_x, train_y, x)
prediction_mean = prediction[0]
prediction_stddev = np.diagonal( prediction[1] )

# %%
fig = plt.figure()
axis = fig.add_subplot(111)
axis.plot( x, np.sin(x) + 0.5 )
axis.errorbar(x, prediction_mean, prediction_stddev)
axis.scatter(train_x, train_y)

# %%
train_x, train_y = data_x[:10], data_y[:10]
prediction = GP(train_x, train_y, x)
prediction_mean = prediction[0]
prediction_stddev = np.diagonal( prediction[1] )

# %%
fig = plt.figure()
axis = fig.add_subplot(111)
axis.plot( x, np.sin(x) + 0.5)
axis.errorbar(x, prediction_mean, prediction_stddev)
axis.scatter(train_x, train_y)

# %%
train_x, train_y = data_x, data_y

# %%
prediction = GP(train_x, train_y, x)
prediction_mean = prediction[0]
prediction_stddev = np.diagonal( prediction[1] )

# %%
fig = plt.figure()
axis = fig.add_subplot(111)
axis.plot( x, np.sin(x) + 0.5 )
axis.errorbar(x, prediction_mean, prediction_stddev)
axis.scatter(train_x, train_y)

# %% [markdown]
# ## Gaussian Process with noise

# %%
def mu(covariance, y):
    _y = np.matmul( covariance, y ).T
    _ =  _y / np.sum( covariance, axis=1 )
    return _

def GP(train_x, train_y, test_x, noise=1.0):
    noise_mat = np.eye( len(train_x) ) * noise
    K = np.array( [[k(x, y) for y in train_x] for x in train_x] ) + noise_mat

    # for test
    K_star_star = np.array( [[k(x, y) for y in test_x] for x in test_x] )
    K_star = np.array( [[k(x, y) for y in test_x] for x in train_x])
    
    t = np.matmul( K_star.T, np.linalg.pinv(K) )
    mu_star = mu(K_star.T, train_y) + np.matmul(t, (train_y - mu(K, train_y)) )
    sigma_star = K_star_star - np.matmul( t, K_star )
    
    return mu_star, sigma_star

# %%
train_x, train_y = data_x[:5], data_y[:5]

prediction = GP(train_x, train_y, x)
prediction_mean = prediction[0]
prediction_stddev = np.diagonal( prediction[1] )

fig = plt.figure()
axis = fig.add_subplot(111)
axis.plot( x, np.sin(x) + 0.5 )
axis.errorbar(x, prediction_mean, prediction_stddev)
axis.scatter(train_x, train_y)

# %% [markdown]
# ### noise data

# %%
import numpy as np
from sklearn import datasets
data_x, data_y = datasets.make_regression(n_samples=200, n_features=1, noise=3.0)
y_min_max = (np.max( data_y ) - np.min( data_y ))
data_y = np.sin( data_y / y_min_max * np.pi * 2.0 )

import matplotlib.pyplot as plt
# %matplotlib inline

x = np.arange(-3.0, 3.0, 0.1)

fig = plt.figure()
axis = fig.add_subplot(111)
axis.scatter(data_x, data_y, c=data_y)

# %% [markdown]
# ### without noise Gaussian Process

# %%
train_x, train_y = data_x, data_y

prediction = GP(train_x, train_y, x, noise=0.0)
prediction_mean = prediction[0]
prediction_stddev = np.diagonal( prediction[1] )

fig = plt.figure()
axis = fig.add_subplot(111)
axis.errorbar(x, prediction_mean, prediction_stddev)
axis.scatter(train_x, train_y)

# %% [markdown]
# ### with noise Gaussian Process

# %%
train_x, train_y = data_x, data_y

prediction = GP(train_x, train_y, x, noise=1.0)
prediction_mean = prediction[0]
prediction_stddev = np.diagonal( prediction[1] )

fig = plt.figure()
axis = fig.add_subplot(111)
axis.errorbar(x, prediction_mean, prediction_stddev)
axis.scatter(train_x, train_y)

# %% [markdown]
# ## Multi-dimensional GP

# %%
import numpy as np
from sklearn import datasets
N_FEATURE_DIMS = 2

data_x, data_y = datasets.make_regression(n_samples=300, n_features=N_FEATURE_DIMS, noise=2.0)
data_y = np.sin( (data_y - data_y.min()) / data_y.max() * np.pi * 2.0 )

import matplotlib.pyplot as plt
# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

figs, axes = plt.subplots(N_FEATURE_DIMS, 1, figsize=(6, 3*N_FEATURE_DIMS))
for i in range(N_FEATURE_DIMS):
    axes[i].scatter(data_x[:, i], data_y, c=data_y)
    axes[i].set_title('axis: {}'.format(i+1))

fig = plt.figure()
axis = fig.add_subplot(111, projection='3d')
axis.scatter(data_x[:,0], data_x[:,1], data_y, c=data_y)

# %%
train_x, train_y = data_x[:100], data_y[:100]

xx = []
xx.append( np.array( [np.arange(-3.0, 3.0, 0.1), np.zeros_like(np.arange(-3.0, 3.0, 0.1))] ).T )
xx.append( np.array( [np.zeros_like(np.arange(-3.0, 3.0, 0.1)), np.arange(-3.0, 3.0, 0.1)] ).T )

prediction = [GP(train_x, train_y, v, noise=1.0) for v in xx]
prediction_mean = [v[0] for v in prediction]
prediction_stddev = [np.diagonal( v[1] ) for v in prediction]

figs, axes = plt.subplots(N_FEATURE_DIMS, 1, figsize=(6, 3*N_FEATURE_DIMS))
for i in range(N_FEATURE_DIMS):
    axes[i].errorbar(xx[i][:, i], prediction_mean[i], prediction_stddev[i])
    axes[i].scatter(data_x[:, i], data_y, c=data_y)
    axes[i].set_title('axis: {}'.format(i+1))


u = np.arange(-3.0, 3.0, 0.5)
v = np.arange(-3.0, 3.0, 0.5)
x, y = np.meshgrid(u, v)
t = np.concatenate((x.reshape(1, -1), y.reshape(1, -1))).T
z = GP(train_x, train_y, t)[0].reshape( x.shape )

fig = plt.figure()
axis = fig.gca(projection='3d')
axis.plot_surface(x, y, z, rstride=1, cstride=1, alpha=0.3)
cset = axis.contourf(x, y, z, zdir='z', offset=-1.0, cmap=cm.coolwarm, alpha=0.5)
cset = axis.contourf(x, y, z, zdir='x', offset=-3.0, cmap=cm.coolwarm, alpha=0.5)
#cset = axis.contourf(x, y, z, zdir='y', offset=3.0, cmap=cm.coolwarm, alpha=0.5)

axis.set_xlabel('X1')
axis.set_xlim(-3, 3)
axis.set_ylabel('X2')
axis.set_ylim(-3, 3)
axis.set_zlabel('y')
axis.set_zlim(-1, 1)

axis.scatter(data_x[:,0], data_x[:,1], data_y, c=data_y)

plt.show()
